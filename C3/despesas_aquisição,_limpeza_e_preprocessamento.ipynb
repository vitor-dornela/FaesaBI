# %% [markdown]
# <a href="https://colab.research.google.com/github/vitor-dornela/FaesaBI/blob/main/C3/despesas_aquisi%C3%A7%C3%A3o%2C_limpeza_e_preprocessamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # fonte dos dados https://transparencia.vitoria.es.gov.br/DadosAbertos.Lista.aspx

# %%
# !wget --user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36" -O despesas_vitoria_2026.xlsx "https://wstransparencia.vitoria.es.gov.br/api/despesas/xlsx?exercicio=2026&tipoDespesa=P"

# !wget --user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36" -O despesas_vitoria_2026_P.csv "https://wstransparencia.vitoria.es.gov.br/api/despesas/csv?exercicio=2026&tipoDespesa=P"
# Out:
# --2026-06-07 22:58:26--  https://wstransparencia.vitoria.es.gov.br/api/despesas/xlsx?exercicio=2026&tipoDespesa=P
# Resolving wstransparencia.vitoria.es.gov.br (wstransparencia.vitoria.es.gov.br)... 45.167.16.164
# Connecting to wstransparencia.vitoria.es.gov.br (wstransparencia.vitoria.es.gov.br)|45.167.16.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1021405 (997K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘despesas_vitoria_2026.xlsx’
#
# despesas_vitoria_20 100%[===================>] 997.47K   507KB/s    in 2.0s
#
# 2026-06-07 22:58:30 (507 KB/s) - ‘despesas_vitoria_2026.xlsx’ saved [1021405/1021405]
#
# --2026-06-07 22:58:30--  https://wstransparencia.vitoria.es.gov.br/api/despesas/csv?exercicio=2026&tipoDespesa=P
# Resolving wstransparencia.vitoria.es.gov.br (wstransparencia.vitoria.es.gov.br)... 45.167.16.164
# ...

# %%
# !file -i *.csv
# !head -n 3 *.csv
# Out:
# despesas_vitoria_2026_P.csv: text/csv; charset=unknown-8bit
# Ano,ValorOrcado,ValorAutorizado,ValorReservado,ValorEmpenhado,ValorLiquidado,ValorPago,CodUnidadeOrcamentaria,UnidadeOrcamentaria,CodUnidadeGestora,UnidadeGestora,CodOrgao,Orgao,CodFuncao,Funcao,CodSubFuncao,SubFuncao,CodPrograma,Programa,CodAcao,Acao,CodFonte,Fonte,CpfCnpjFornecedor,NumeroProcesso,NumeroContrato,CodNaturezaDespesa,NaturezaDespesa,NomeFornecedor,Data,IdEmpenho,Licitacao,Descricao,NumeroEmpenho
# ...

# %% [markdown]
# ## leitura arquivo excel

# %%
import pandas as pd

dfex = pd.read_excel("despesas_vitoria_2026.xlsx")
dfex.columns
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['NumeroPagamento', 'ProcessoPagamento', 'DigitoPagamento', 'idEmpenho',
#        'NumeroEmpenho', 'NumeroLiquidacao', 'Exercicio', 'Data', 'Descricao',
#        'Licitacao', 'UnidadeGestoraEmpenho', 'CodUnidadeGestoraEmpenho',
#        'Valor', 'CpfCnpjFornecedor', 'NomeFornecedor'],
#       dtype='object')

# %%
dfex.groupby("UnidadeGestoraEmpenho")['Valor'].describe()
# Out:
#                                                      count           mean  \
# UnidadeGestoraEmpenho
# CDTIV - Cia de Desenvolvimento, Turismo e Inova...   508.0   31851.257520
# CENTRAL DE SERVIÇOS                                 1289.0  114899.720403
# CONTROLADORIA GERAL DO MUNICIPIO                     200.0    6341.146000
# CÂMARA MUNICIPAL DE VITÓRIA                    ...   651.0   35187.694255
# FUNDO AMBIENTAL                                       59.0   14714.664915
# FUNDO DE TECNOLOGIA - FACITEC                          1.0    1198.000000
# FUNDO FINANCEIRO                                     241.0  541422.748008
# FUNDO MUN. INFANCIA E ADOLESCENCIA                     3.0  198999.336667
# FUNDO MUNICIPAL DE ASSISTÊNCIA SOCIAL DE VITORIA    1026.0   30716.780097
# FUNDO MUNICIPAL DE COMBATE À CORRUPÇÃO                 1.0    1050.000000
# FUNDO MUNICIPAL DE CULTURA                            69.0   17595.377826
# ...

# %% [markdown]
# ## leitura arquivo csv

# %%
dfcsv = pd.read_csv("despesas_vitoria_2026_P.csv", encoding='LATIN1', sep=',',
                     engine='python', on_bad_lines='warn')
# Out:
# /tmp/ipykernel_1498/2771002194.py:1: ParserWarning: Skipping line 7: ',' expected after '"'
#
#   dfcsv = pd.read_csv("despesas_vitoria_2026_P.csv", encoding='LATIN1', sep=',',
# /tmp/ipykernel_1498/2771002194.py:1: ParserWarning: Skipping line 8: ',' expected after '"'
#
#   dfcsv = pd.read_csv("despesas_vitoria_2026_P.csv", encoding='LATIN1', sep=',',
# /tmp/ipykernel_1498/2771002194.py:1: ParserWarning: Skipping line 9: ',' expected after '"'
#
#   dfcsv = pd.read_csv("despesas_vitoria_2026_P.csv", encoding='LATIN1', sep=',',
# /tmp/ipykernel_1498/2771002194.py:1: ParserWarning: Skipping line 10: ',' expected after '"'
#
#   dfcsv = pd.read_csv("despesas_vitoria_2026_P.csv", encoding='LATIN1', sep=',',
# /tmp/ipykernel_1498/2771002194.py:1: ParserWarning: Skipping line 12: ',' expected after '"'
#
#   dfcsv = pd.read_csv("despesas_vitoria_2026_P.csv", encoding='LATIN1', sep=',',
# /tmp/ipykernel_1498/2771002194.py:1: ParserWarning: Skipping line 19: ',' expected after '"'
#
# ...

# %%
dfcsv.sample(1)
# Out:
#        Ano ValorOrcado ValorAutorizado ValorReservado ValorEmpenhado  \
# 7063  2026         NaN             NaN            NaN         235,14
#
#      ValorLiquidado ValorPago  CodUnidadeOrcamentaria  UnidadeOrcamentaria  \
# 7063         235,14    235,14                     NaN                  NaN
#
#       CodUnidadeGestora  ... NumeroProcesso  NumeroContrato  \
# 7063              214.0  ...    117727/2025   Não informado
#
#      CodNaturezaDespesa                                    NaturezaDespesa  \
# 7063         33909250.0  MULTAS E JUROS                                ...
#
#                          NomeFornecedor                 Data  IdEmpenho  \
# 7063  FUNDO MUNICIPAL DE EDUCACAO - FME  25/02/2026 00:00:00  3165938.0
#
#           Licitacao                                          Descricao  \
# 7063  Não informado  Referente à juros /multa pelo atraso no pagame...
#
#       NumeroEmpenho
# 7063       925/2026
#
# [1 rows x 34 columns]

# %% [markdown]
# # listagem das linhas com erro

# %%
import os
import sys

# ----------------------------------------------------------------------
# List of line numbers (1-indexed) that were skipped due to parsing errors.
# Extracted from the ParserWarning log you provided.
# ----------------------------------------------------------------------
problematic_lines = [
    7, 8, 9, 10, 12, 19, 20, 820, 889, 1029, 1054, 1984, 2443, 2489, 2490,
    2492, 2627, 3980, 4225, 4227, 4339, 5826, 5830, 5832, 5845, 7233, 7280,
    8568, 10002, 10342, 10344, 10416, 10418, 10420, 10422, 10424, 11570,
    11730, 11873, 11874, 13150, 13151, 13152, 13162, 13171, 13176, 13177,
    13180, 13181, 13185, 13188, 13189, 13190, 13198, 13264, 13278, 13279,
    13280, 13281, 13282, 13283, 13284, 13285, 13326, 13327, 13329, 13351,
    13412, 13413, 13414, 13416, 13417, 13483, 13487, 14763
]

# ----------------------------------------------------------------------
# File name (adjust if your CSV is in a different directory)
# ----------------------------------------------------------------------
csv_file = "despesas_vitoria_2026_P.csv"

# ----------------------------------------------------------------------
# Check if file exists
# ----------------------------------------------------------------------
if not os.path.isfile(csv_file):
    print(f"Error: File '{csv_file}' not found in the current directory.")
    sys.exit(1)

# ----------------------------------------------------------------------
# Read and display the problematic lines
# ----------------------------------------------------------------------
print(f"\nDisplaying problematic lines from '{csv_file}':\n")
print("-" * 80)

with open(csv_file, 'r', encoding='latin1') as f:
    for current_line_num, raw_line in enumerate(f, start=1):
        if current_line_num in problematic_lines:
            # Show line number and the raw line content (strip trailing newline)
            print(f"Line {current_line_num:>5} : {raw_line.rstrip()}")

print("-" * 80)
print(f"\nTotal problematic lines listed: {len(problematic_lines)}")
# Out:
# Displaying problematic lines from 'despesas_vitoria_2026_P.csv':
#
# --------------------------------------------------------------------------------
# Line     7 : 2026,,,,"10000,00","10000,00","10000,00",,,221               ,SECRETARIA DE CULTURA,210000,SECRETARIA DE CULTURA,13,Cultura,392,Difusão Cultural,0022,Vitória Criativa,2045,Produção e Difusão Cultural,1.500.0000.0000,RECURSOS NÃO VINCULADOS DE IMPOSTOS,32.691.882/0001-75  ,89520/2025,520/2025,33903922 ,"EXPOSICOES, CONGRESSOS E CONFERENCIAS             ",KALIL DE CARVALHO LIMA 14361561737,02/01/2026 00:00:00,3141919,280/2025,"CONTRATO 520/2025 - PRESTAÇÃO DE SERVIÇO DA ATRAÇÃO "ENGESAMBA", PARA REALIZAÇÃO DE UMA APRESENTAÇÃO NA "ARENA VERÃO" NO DIA 03 DE JANEIRO DE 2026, NA PRAIA DE CAMBURI, VITÓRIA/ES. PROCESSO 8952010/2025 - EXERCÍCIO/2026.",3/2026
# ...
